# %% [markdown]
# <a href="https://colab.research.google.com/github/tanatet8/Colab_Script/blob/main/youtube_transcript_extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ส่วนใหม่

# %%
# !pip install youtube-transcript-api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.1 MB/s eta 0:00:00
# ...

# %%
# 🧠 Import library
from youtube_transcript_api import YouTubeTranscriptApi

# 🔗 ลิงก์ YouTube ที่จะดึง transcript
video_url = "https://www.youtube.com/watch?v=GKCBpj9FQXU"  # เปลี่ยนลิงก์ได้
video_id = video_url.split("v=")[-1]

# 🎯 ดึง transcript
try:
    transcript = YouTubeTranscriptApi.get_transcript(video_id)

    # ✅ แสดง transcript พร้อมเวลา
    print("✅ Transcript:\n")
    for entry in transcript:
        print(f"{entry['start']:.2f}s - {entry['text']}")

    # 💾 รวมข้อความทั้งหมด
    full_text = '\n'.join([entry['text'] for entry in transcript])

    # 💾 เซฟเป็นไฟล์ .txt
    with open("transcript.txt", "w", encoding="utf-8") as f:
        f.write(full_text)
    print("\n💾 Transcript saved as 'transcript.txt'")

except Exception as e:
    print("❌ Error:", e)
# Out:
# ✅ Transcript:
#
# 0.08s - If you want to make real money in 2025
# 2.00s - selling AI systems, I want you to please
# 4.00s - do yourself a favor and stay away from
# 5.76s - single use case AI automations and AI
# 7.92s - agents. Instead, you should build out
# 10.08s - entire AI applications and
# 11.92s - infrastructure. And I know this might
# 13.44s - sound counterintuitive. It might sound a
# 14.88s - little bit too technical and complex,
# 16.56s - but it's really not as complex as you
# 18.16s - think it is. And you'll probably hear
# 20.16s - everyone on the internet telling you to
# 21.52s - build out this simple Make.com system to
# 23.44s - sell for 20 grand, but I can tell you
# 25.36s - that's just not how it works. I should
# 27.20s - mention that I've personally built and
# 28.48s - sold over 80 grand worth of automation
# 30.16s - systems in the past eight months. What
# 32.40s - I've consistently found is that clients
# ...
